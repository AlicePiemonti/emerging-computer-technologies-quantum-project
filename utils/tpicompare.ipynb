# %% [markdown]
# # Compare Topological Assignment Improved and version2

# %%
from TPImprovedV2 import TopologicalAssignmentImprovedv2
from TPImproved import TopologicalAssignmentImproved
from SwapModified import BasicSwapModified
from cost import *

from qiskit import QuantumCircuit
from qiskit.test.mock.backends import FakeBrooklyn
from qiskit.transpiler import Layout, CouplingMap

from qiskit.converters import circuit_to_dag
from qiskit.dagcircuit import DAGCircuit
from qiskit.converters import dag_to_circuit

import os
from tabulate import tabulate

# %%
# info device 65 qubits -- create DAG with 65 qubits
backend = FakeBrooklyn()
num_qubits =  backend.configuration().n_qubits
coupling_list = backend.configuration().coupling_map
coupling_map = CouplingMap(couplinglist=coupling_list)
device_qc = QuantumCircuit(num_qubits, num_qubits)
device_DAG = circuit_to_dag(device_qc)

# %%
def compare_cost(qc, n_most_used):
    # for topological assignment improved - take n most used qubit
    total_cost = []
    for n in range(n_most_used):
        qc_copy = qc.copy()
        new_input_DAG = circuit_to_dag(qc_copy) 

        # build the input_DAG on the device_DAG (65 qubits)
        new_device_qc = QuantumCircuit(num_qubits, num_qubits)
        new_device_DAG = circuit_to_dag(new_device_qc) 
        new_device_DAG.compose(new_input_DAG)

        tpi = TopologicalAssignmentImproved(coupling_map)
        tp_layouti = tpi.run(new_device_DAG, n + 1) # n is from 0 to (n_most_used - 1)
        basic_pass_modifiedi = BasicSwapModified(coupling_map, tp_layouti)
        new_dag_tp_assignmnet_i = basic_pass_modifiedi.run(new_device_DAG)
        cost_tp_assignment_i = compute_cost(new_dag_tp_assignmnet_i)
        total_cost.append(cost_tp_assignment_i)
        print('tp assignment improved - ',n + 1, ' most used qubit - ok \n')
        
        qc_copy2 = qc.copy()
        new_input_DAG2 = circuit_to_dag(qc_copy2) 

        # build the input_DAG on the device_DAG (65 qubits)
        new_device_qc2 = QuantumCircuit(num_qubits, num_qubits)
        new_device_DAG2 = circuit_to_dag(new_device_qc2) 
        new_device_DAG2.compose(new_input_DAG2)

        tpi2 = TopologicalAssignmentImprovedv2(coupling_map)
        tp_layouti2 = tpi2.run(new_device_DAG2, n + 1) # n is from 0 to (n_most_used - 1)
        basic_pass_modifiedi2 = BasicSwapModified(coupling_map, tp_layouti2)
        new_dag_tp_assignmnet_i2 = basic_pass_modifiedi2.run(new_device_DAG2)
        cost_tp_assignment_i2 = compute_cost(new_dag_tp_assignmnet_i2)
        total_cost.append(cost_tp_assignment_i2)
        print('tp assignment improved - v2 - ',n + 1, ' most used qubit - ok \n')
        
    return total_cost

# %%
folderpath = r".\..\original" # make sure to put the 'r' in front
filepaths  = [os.path.join(folderpath, name) for name in os.listdir(folderpath)]
table_rows = []

# for this project we just analyse up to 5 most used qubits
n_most_used = 5

#for i in range(5):
for i in range(len(filepaths)):
    print('------------iteration ', i, '-----------  file: ', filepaths[i], '----------')
    input_path = filepaths[i]
    qc = QuantumCircuit.from_qasm_file(path=input_path)
    costs = compare_cost(qc, n_most_used)
    print('tot------', costs)
    row = [input_path.rsplit('\\', 1)[1]]
    row.extend(costs)
    table_rows.append(row)
# Out:
# ------------iteration  0 -----------  file:  .\..\original\adder-13.qasm ----------
# gates---
#  {'rz': 534, 'rx': 0, 'sx': 26, 'cx': 494, 'swap': 668, 'barrier': 1, 'measure': 26}
#
#
# Cost of the circuit: 25006
# tp assignment improved -  1  most used qubit - ok
#
# gates---
#  {'rz': 534, 'rx': 0, 'sx': 26, 'cx': 494, 'swap': 766, 'barrier': 1, 'measure': 26}
#
#
# Cost of the circuit: 27946
# tp assignment improved - v2 -  1  most used qubit - ok
#
# gates---
#  {'rz': 534, 'rx': 0, 'sx': 26, 'cx': 494, 'swap': 676, 'barrier': 1, 'measure': 26}
#
#
# Cost of the circuit: 25246
# tp assignment improved -  2  most used qubit - ok
#
# gates---
#  {'rz': 534, 'rx': 0, 'sx': 26, 'cx': 494, 'swap': 688, 'barrier': 1, 'measure': 26}
#
#
# Cost of the circuit: 25606
# tp assignment improved - v2 -  2  most used qubit - ok
#
# gates---
#  {'rz': 534, 'rx': 0, 'sx': 26, 'cx': 494, 'swap': 708, 'barrier': 1, 'measure': 26}
#
#
# Cost of the circuit: 26206
# tp assignment improved -  3  most used qubit - ok
#
# gates---
#  {'rz': 534, 'rx': 0, 'sx': 26, 'cx': 494, 'swap': 756, 'barrier': 1, 'measure': 26}
#
#
# Cost of the circuit: 27646
# tp assignment improved - v2 -  3  most used qubit - ok
#
# gates---
#  {'rz': 534, 'rx': 0, 'sx': 26, 'cx': 494, 'swap': 803, 'barrier': 1, 'measure': 26}
#
#
# Cost of the circuit: 29056
# tp assignment improved -  4  most used qubit - ok
#
# gates---
#  {'rz': 534, 'rx': 0, 'sx': 26, 'cx': 494, 'swap': 836, 'barrier': 1, 'measure': 26}
#
#
# Cost of the circuit: 30046
# tp assignment improved - v2 -  4  most used qubit - ok
#
# gates---
#  {'rz': 534, 'rx': 0, 'sx': 26, 'cx': 494, 'swap': 898, 'barrier': 1, 'measure': 26}
#
#
# Cost of the circuit: 31906
# tp assignment improved -  5  most used qubit - ok
#
# gates---
#  {'rz': 534, 'rx': 0, 'sx': 26, 'cx': 494, 'swap': 741, 'barrier': 1, 'measure': 26}
#
#
# Cost of the circuit: 27196
# tp assignment improved - v2 -  5  most used qubit - ok
#
# tot------ [25006, 27946, 25246, 25606, 26206, 27646, 29056, 30046, 31906, 27196]
# ------------iteration  1 -----------  file:  .\..\original\adder-16.qasm ----------
# gates---
#  {'rz': 801, 'rx': 0, 'sx': 32, 'cx': 752, 'swap': 1454, 'barrier': 1, 'measure': 32}
#
#
# Cost of the circuit: 51172
# tp assignment improved -  1  most used qubit - ok
#
# gates---
#  {'rz': 801, 'rx': 0, 'sx': 32, 'cx': 752, 'swap': 1457, 'barrier': 1, 'measure': 32}
#
#
# Cost of the circuit: 51262
# tp assignment improved - v2 -  1  most used qubit - ok
#
# gates---
#  {'rz': 801, 'rx': 0, 'sx': 32, 'cx': 752, 'swap': 1281, 'barrier': 1, 'measure': 32}
#
#
# Cost of the circuit: 45982
# tp assignment improved -  2  most used qubit - ok
#
# gates---
#  {'rz': 801, 'rx': 0, 'sx': 32, 'cx': 752, 'swap': 1231, 'barrier': 1, 'measure': 32}
#
#
# Cost of the circuit: 44482
# tp assignment improved - v2 -  2  most used qubit - ok
#
# gates---
#  {'rz': 801, 'rx': 0, 'sx': 32, 'cx': 752, 'swap': 1342, 'barrier': 1, 'measure': 32}
#
#
# Cost of the circuit: 47812
# tp assignment improved -  3  most used qubit - ok
#
# gates---
#  {'rz': 801, 'rx': 0, 'sx': 32, 'cx': 752, 'swap': 1468, 'barrier': 1, 'measure': 32}
#
#
# Cost of the circuit: 51592
# tp assignment improved - v2 -  3  most used qubit - ok
#
# gates---
#  {'rz': 801, 'rx': 0, 'sx': 32, 'cx': 752, 'swap': 1406, 'barrier': 1, 'measure': 32}
#
#
# Cost of the circuit: 49732
# tp assignment improved -  4  most used qubit - ok
#
# gates---
#  {'rz': 801, 'rx': 0, 'sx': 32, 'cx': 752, 'swap': 1546, 'barrier': 1, 'measure': 32}
#
#
# Cost of the circuit: 53932
# tp assignment improved - v2 -  4  most used qubit - ok
#
# gates---
#  {'rz': 801, 'rx': 0, 'sx': 32, 'cx': 752, 'swap': 1663, 'barrier': 1, 'measure': 32}
#
#
# Cost of the circuit: 57442
# tp assignment improved -  5  most used qubit - ok
#
# gates---
#  {'rz': 801, 'rx': 0, 'sx': 32, 'cx': 752, 'swap': 1296, 'barrier': 1, 'measure': 32}
#
#
# Cost of the circuit: 46432
# tp assignment improved - v2 -  5  most used qubit - ok
#
# tot------ [51172, 51262, 45982, 44482, 47812, 51592, 49732, 53932, 57442, 46432]
# ------------iteration  2 -----------  file:  .\..\original\adder-3.qasm ----------
# gates---
#  {'rz': 34, 'rx': 0, 'sx': 6, 'cx': 24, 'swap': 11, 'barrier': 1, 'measure': 6}
#
#
# Cost of the circuit: 576
# tp assignment improved -  1  most used qubit - ok
#
# gates---
#  {'rz': 34, 'rx': 0, 'sx': 6, 'cx': 24, 'swap': 10, 'barrier': 1, 'measure': 6}
#
#
# Cost of the circuit: 546
# tp assignment improved - v2 -  1  most used qubit - ok
#
# gates---
#  {'rz': 34, 'rx': 0, 'sx': 6, 'cx': 24, 'swap': 11, 'barrier': 1, 'measure': 6}
#
#
# Cost of the circuit: 576
# tp assignment improved -  2  most used qubit - ok
#
# gates---
#  {'rz': 34, 'rx': 0, 'sx': 6, 'cx': 24, 'swap': 10, 'barrier': 1, 'measure': 6}
#
#
# Cost of the circuit: 546
# tp assignment improved - v2 -  2  most used qubit - ok
#
# gates---
#  {'rz': 34, 'rx': 0, 'sx': 6, 'cx': 24, 'swap': 11, 'barrier': 1, 'measure': 6}
#
#
# Cost of the circuit: 576
# tp assignment improved -  3  most used qubit - ok
#
# gates---
#  {'rz': 34, 'rx': 0, 'sx': 6, 'cx': 24, 'swap': 13, 'barrier': 1, 'measure': 6}
#
#
# Cost of the circuit: 636
# tp assignment improved - v2 -  3  most used qubit - ok
#
# gates---
#  {'rz': 34, 'rx': 0, 'sx': 6, 'cx': 24, 'swap': 11, 'barrier': 1, 'measure': 6}
#
#
# Cost of the circuit: 576
# tp assignment improved -  4  most used qubit - ok
#
# gates---
#  {'rz': 34, 'rx': 0, 'sx': 6, 'cx': 24, 'swap': 13, 'barrier': 1, 'measure': 6}
#
#
# Cost of the circuit: 636
# tp assignment improved - v2 -  4  most used qubit - ok
#
# gates---
#  {'rz': 34, 'rx': 0, 'sx': 6, 'cx': 24, 'swap': 10, 'barrier': 1, 'measure': 6}
#
#
# Cost of the circuit: 546
# tp assignment improved -  5  most used qubit - ok
#
# gates---
#  {'rz': 34, 'rx': 0, 'sx': 6, 'cx': 24, 'swap': 12, 'barrier': 1, 'measure': 6}
#
#
# Cost of the circuit: 606
# tp assignment improved - v2 -  5  most used qubit - ok
#
# tot------ [576, 546, 576, 546, 576, 636, 576, 636, 546, 606]
# ------------iteration  3 -----------  file:  .\..\original\adder-8.qasm ----------
# gates---
#  {'rz': 209, 'rx': 0, 'sx': 16, 'cx': 184, 'swap': 176, 'barrier': 1, 'measure': 16}
#
#
# Cost of the circuit: 7136
# tp assignment improved -  1  most used qubit - ok
#
# gates---
#  {'rz': 209, 'rx': 0, 'sx': 16, 'cx': 184, 'swap': 189, 'barrier': 1, 'measure': 16}
#
#
# Cost of the circuit: 7526
# tp assignment improved - v2 -  1  most used qubit - ok
#
# gates---
#  {'rz': 209, 'rx': 0, 'sx': 16, 'cx': 184, 'swap': 169, 'barrier': 1, 'measure': 16}
#
#
# Cost of the circuit: 6926
# tp assignment improved -  2  most used qubit - ok
#
# gates---
#  {'rz': 209, 'rx': 0, 'sx': 16, 'cx': 184, 'swap': 174, 'barrier': 1, 'measure': 16}
#
#
# Cost of the circuit: 7076
# tp assignment improved - v2 -  2  most used qubit - ok
#
# gates---
#  {'rz': 209, 'rx': 0, 'sx': 16, 'cx': 184, 'swap': 181, 'barrier': 1, 'measure': 16}
#
#
# Cost of the circuit: 7286
# tp assignment improved -  3  most used qubit - ok
#
# gates---
#  {'rz': 209, 'rx': 0, 'sx': 16, 'cx': 184, 'swap': 213, 'barrier': 1, 'measure': 16}
#
#
# Cost of the circuit: 8246
# tp assignment improved - v2 -  3  most used qubit - ok
#
# gates---
#  {'rz': 209, 'rx': 0, 'sx': 16, 'cx': 184, 'swap': 208, 'barrier': 1, 'measure': 16}
#
#
# Cost of the circuit: 8096
# tp assignment improved -  4  most used qubit - ok
#
# gates---
#  {'rz': 209, 'rx': 0, 'sx': 16, 'cx': 184, 'swap': 212, 'barrier': 1, 'measure': 16}
#
#
# Cost of the circuit: 8216
# tp assignment improved - v2 -  4  most used qubit - ok
#
# gates---
#  {'rz': 209, 'rx': 0, 'sx': 16, 'cx': 184, 'swap': 195, 'barrier': 1, 'measure': 16}
#
#
# Cost of the circuit: 7706
# tp assignment improved -  5  most used qubit - ok
#
# gates---
#  {'rz': 209, 'rx': 0, 'sx': 16, 'cx': 184, 'swap': 206, 'barrier': 1, 'measure': 16}
#
#
# Cost of the circuit: 8036
# tp assignment improved - v2 -  5  most used qubit - ok
#
# tot------ [7136, 7526, 6926, 7076, 7286, 8246, 8096, 8216, 7706, 8036]
# ------------iteration  4 -----------  file:  .\..\original\ghz_state-16.qasm ----------
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 15, 'swap': 0, 'measure': 16}
#
#
# Cost of the circuit: 151
# tp assignment improved -  1  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 15, 'swap': 0, 'measure': 16}
#
#
# Cost of the circuit: 151
# tp assignment improved - v2 -  1  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 15, 'swap': 0, 'measure': 16}
#
#
# Cost of the circuit: 151
# tp assignment improved -  2  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 15, 'swap': 0, 'measure': 16}
#
#
# Cost of the circuit: 151
# tp assignment improved - v2 -  2  most used qubit - ok
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 15, 'swap': 0, 'measure': 16}
#
#
# Cost of the circuit: 151
# tp assignment improved -  3  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 15, 'swap': 1, 'measure': 16}
#
#
# Cost of the circuit: 181
# tp assignment improved - v2 -  3  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 15, 'swap': 1, 'measure': 16}
#
#
# Cost of the circuit: 181
# tp assignment improved -  4  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 15, 'swap': 0, 'measure': 16}
#
#
# Cost of the circuit: 151
# tp assignment improved - v2 -  4  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 15, 'swap': 1, 'measure': 16}
#
#
# Cost of the circuit: 181
# tp assignment improved -  5  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 15, 'swap': 0, 'measure': 16}
#
#
# Cost of the circuit: 151
# tp assignment improved - v2 -  5  most used qubit - ok
#
# tot------ [151, 151, 151, 151, 151, 181, 181, 151, 181, 151]
# ------------iteration  5 -----------  file:  .\..\original\ghz_state-27.qasm ----------
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 26, 'swap': 1, 'measure': 27}
#
#
# Cost of the circuit: 291
# tp assignment improved -  1  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 26, 'swap': 1, 'measure': 27}
#
#
# Cost of the circuit: 291
# tp assignment improved - v2 -  1  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 26, 'swap': 1, 'measure': 27}
#
#
# Cost of the circuit: 291
# tp assignment improved -  2  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 26, 'swap': 0, 'measure': 27}
#
#
# Cost of the circuit: 261
# tp assignment improved - v2 -  2  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 26, 'swap': 0, 'measure': 27}
#
#
# Cost of the circuit: 261
# tp assignment improved -  3  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 26, 'swap': 1, 'measure': 27}
#
#
# Cost of the circuit: 291
# tp assignment improved - v2 -  3  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 26, 'swap': 1, 'measure': 27}
#
#
# Cost of the circuit: 291
# tp assignment improved -  4  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 26, 'swap': 1, 'measure': 27}
#
#
# Cost of the circuit: 291
# tp assignment improved - v2 -  4  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 26, 'swap': 0, 'measure': 27}
#
#
# Cost of the circuit: 261
# tp assignment improved -  5  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 26, 'swap': 1, 'measure': 27}
#
#
# Cost of the circuit: 291
# tp assignment improved - v2 -  5  most used qubit - ok
#
# tot------ [291, 291, 291, 261, 261, 291, 291, 291, 261, 291]
# ------------iteration  6 -----------  file:  .\..\original\ghz_state-5.qasm ----------
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 4, 'swap': 0, 'measure': 5}
#
#
# Cost of the circuit: 41
# tp assignment improved -  1  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 4, 'swap': 0, 'measure': 5}
#
#
# Cost of the circuit: 41
# tp assignment improved - v2 -  1  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 4, 'swap': 0, 'measure': 5}
#
#
# Cost of the circuit: 41
# tp assignment improved -  2  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 4, 'swap': 0, 'measure': 5}
#
#
# Cost of the circuit: 41
# tp assignment improved - v2 -  2  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 4, 'swap': 0, 'measure': 5}
#
#
# Cost of the circuit: 41
# tp assignment improved -  3  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 4, 'swap': 0, 'measure': 5}
#
#
# Cost of the circuit: 41
# tp assignment improved - v2 -  3  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 4, 'swap': 4, 'measure': 5}
#
#
# Cost of the circuit: 161
# tp assignment improved -  4  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 4, 'swap': 4, 'measure': 5}
#
#
# Cost of the circuit: 161
# tp assignment improved - v2 -  4  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 4, 'swap': 3, 'measure': 5}
#
#
# Cost of the circuit: 131
# tp assignment improved -  5  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 4, 'swap': 3, 'measure': 5}
#
#
# Cost of the circuit: 131
# tp assignment improved - v2 -  5  most used qubit - ok
#
# tot------ [41, 41, 41, 41, 41, 41, 161, 161, 131, 131]
# ------------iteration  7 -----------  file:  .\..\original\ghz_state-65.qasm ----------
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 64, 'swap': 24, 'measure': 65}
#
#
# Cost of the circuit: 1361
# tp assignment improved -  1  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 64, 'swap': 24, 'measure': 65}
#
#
# Cost of the circuit: 1361
# tp assignment improved - v2 -  1  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 64, 'swap': 16, 'measure': 65}
#
#
# Cost of the circuit: 1121
# tp assignment improved -  2  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 64, 'swap': 32, 'measure': 65}
#
#
# Cost of the circuit: 1601
# tp assignment improved - v2 -  2  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 64, 'swap': 24, 'measure': 65}
#
#
# Cost of the circuit: 1361
# tp assignment improved -  3  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 64, 'swap': 26, 'measure': 65}
#
#
# Cost of the circuit: 1421
# tp assignment improved - v2 -  3  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 64, 'swap': 22, 'measure': 65}
#
#
# Cost of the circuit: 1301
# tp assignment improved -  4  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 64, 'swap': 18, 'measure': 65}
#
#
# Cost of the circuit: 1181
# tp assignment improved - v2 -  4  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 64, 'swap': 24, 'measure': 65}
#
#
# Cost of the circuit: 1361
# tp assignment improved -  5  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 64, 'swap': 30, 'measure': 65}
#
#
# Cost of the circuit: 1541
# tp assignment improved - v2 -  5  most used qubit - ok
#
# tot------ [1361, 1361, 1121, 1601, 1361, 1421, 1301, 1181, 1361, 1541]
# ------------iteration  8 -----------  file:  .\..\original\ghz_state-7.qasm ----------
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 6, 'swap': 0, 'measure': 7}
#
#
# Cost of the circuit: 61
# tp assignment improved -  1  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 6, 'swap': 0, 'measure': 7}
#
#
# Cost of the circuit: 61
# tp assignment improved - v2 -  1  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 6, 'swap': 0, 'measure': 7}
#
#
# Cost of the circuit: 61
# tp assignment improved -  2  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 6, 'swap': 0, 'measure': 7}
#
#
# Cost of the circuit: 61
# tp assignment improved - v2 -  2  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 6, 'swap': 0, 'measure': 7}
#
#
# Cost of the circuit: 61
# tp assignment improved -  3  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 6, 'swap': 0, 'measure': 7}
#
#
# Cost of the circuit: 61
# tp assignment improved - v2 -  3  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 6, 'swap': 0, 'measure': 7}
#
#
# Cost of the circuit: 61
# tp assignment improved -  4  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 6, 'swap': 0, 'measure': 7}
#
#
# Cost of the circuit: 61
# tp assignment improved - v2 -  4  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 6, 'swap': 0, 'measure': 7}
#
#
# Cost of the circuit: 61
# tp assignment improved -  5  most used qubit - ok
#
# gates---
#  {'rz': 2, 'rx': 0, 'sx': 1, 'cx': 6, 'swap': 0, 'measure': 7}
#
#
# Cost of the circuit: 61
# tp assignment improved - v2 -  5  most used qubit - ok
#
# tot------ [61, 61, 61, 61, 61, 61, 61, 61, 61, 61]
# ------------iteration  9 -----------  file:  .\..\original\grover-3.qasm ----------
# gates---
#  {'rz': 73, 'rx': 0, 'sx': 26, 'cx': 48, 'swap': 13, 'x': 4, 'measure': 3}
#
#
# Cost of the circuit: 896
# tp assignment improved -  1  most used qubit - ok
#
# gates---
#  {'rz': 73, 'rx': 0, 'sx': 26, 'cx': 48, 'swap': 13, 'x': 4, 'measure': 3}
#
#
# Cost of the circuit: 896
# tp assignment improved - v2 -  1  most used qubit - ok
#
# gates---
#  {'rz': 73, 'rx': 0, 'sx': 26, 'cx': 48, 'swap': 13, 'x': 4, 'measure': 3}
#
#
# Cost of the circuit: 896
# tp assignment improved -  2  most used qubit - ok
# gates---
#  {'rz': 73, 'rx': 0, 'sx': 26, 'cx': 48, 'swap': 13, 'x': 4, 'measure': 3}
#
#
# Cost of the circuit: 896
# tp assignment improved - v2 -  2  most used qubit - ok
#
# gates---
#  {'rz': 73, 'rx': 0, 'sx': 26, 'cx': 48, 'swap': 28, 'x': 4, 'measure': 3}
#
#
# Cost of the circuit: 1346
# tp assignment improved -  3  most used qubit - ok
#
# gates---
#  {'rz': 73, 'rx': 0, 'sx': 26, 'cx': 48, 'swap': 28, 'x': 4, 'measure': 3}
#
#
# Cost of the circuit: 1346
# tp assignment improved - v2 -  3  most used qubit - ok
#
# gates---
#  {'rz': 73, 'rx': 0, 'sx': 26, 'cx': 48, 'swap': 28, 'x': 4, 'measure': 3}
#
#
# Cost of the circuit: 1346
# tp assignment improved -  4  most used qubit - ok
#
# gates---
#  {'rz': 73, 'rx': 0, 'sx': 26, 'cx': 48, 'swap': 28, 'x': 4, 'measure': 3}
#
#
# Cost of the circuit: 1346
# tp assignment improved - v2 -  4  most used qubit - ok
#
# gates---
#  {'rz': 73, 'rx': 0, 'sx': 26, 'cx': 48, 'swap': 34, 'x': 4, 'measure': 3}
#
#
# Cost of the circuit: 1526
# tp assignment improved -  5  most used qubit - ok
#
# gates---
#  {'rz': 73, 'rx': 0, 'sx': 26, 'cx': 48, 'swap': 34, 'x': 4, 'measure': 3}
#
#
# Cost of the circuit: 1526
# tp assignment improved - v2 -  5  most used qubit - ok
#
# tot------ [896, 896, 896, 896, 1346, 1346, 1346, 1346, 1526, 1526]
# ------------iteration  10 -----------  file:  .\..\original\grover-4.qasm ----------
# gates---
#  {'rz': 158, 'rx': 0, 'sx': 57, 'cx': 108, 'swap': 78, 'x': 6, 'measure': 4}
#
#
# Cost of the circuit: 3477
# tp assignment improved -  1  most used qubit - ok
#
# gates---
#  {'rz': 158, 'rx': 0, 'sx': 57, 'cx': 108, 'swap': 78, 'x': 6, 'measure': 4}
#
#
# Cost of the circuit: 3477
# tp assignment improved - v2 -  1  most used qubit - ok
#
# gates---
#  {'rz': 158, 'rx': 0, 'sx': 57, 'cx': 108, 'swap': 78, 'x': 6, 'measure': 4}
#
#
# Cost of the circuit: 3477
# tp assignment improved -  2  most used qubit - ok
#
# gates---
#  {'rz': 158, 'rx': 0, 'sx': 57, 'cx': 108, 'swap': 78, 'x': 6, 'measure': 4}
#
#
# Cost of the circuit: 3477
# tp assignment improved - v2 -  2  most used qubit - ok
#
# gates---
#  {'rz': 158, 'rx': 0, 'sx': 57, 'cx': 108, 'swap': 81, 'x': 6, 'measure': 4}
#
#
# Cost of the circuit: 3567
# tp assignment improved -  3  most used qubit - ok
#
# gates---
#  {'rz': 158, 'rx': 0, 'sx': 57, 'cx': 108, 'swap': 92, 'x': 6, 'measure': 4}
#
#
# Cost of the circuit: 3897
# tp assignment improved - v2 -  3  most used qubit - ok
#
# gates---
#  {'rz': 158, 'rx': 0, 'sx': 57, 'cx': 108, 'swap': 81, 'x': 6, 'measure': 4}
#
#
# Cost of the circuit: 3567
# tp assignment improved -  4  most used qubit - ok
#
# gates---
#  {'rz': 158, 'rx': 0, 'sx': 57, 'cx': 108, 'swap': 45, 'x': 6, 'measure': 4}
#
#
# Cost of the circuit: 2487
# tp assignment improved - v2 -  4  most used qubit - ok
#
# gates---
#  {'rz': 158, 'rx': 0, 'sx': 57, 'cx': 108, 'swap': 81, 'x': 6, 'measure': 4}
#
#
# Cost of the circuit: 3567
# tp assignment improved -  5  most used qubit - ok
#
# gates---
#  {'rz': 158, 'rx': 0, 'sx': 57, 'cx': 108, 'swap': 81, 'x': 6, 'measure': 4}
#
#
# Cost of the circuit: 3567
# tp assignment improved - v2 -  5  most used qubit - ok
#
# tot------ [3477, 3477, 3477, 3477, 3567, 3897, 3567, 2487, 3567, 3567]
# ------------iteration  11 -----------  file:  .\..\original\grover-5.qasm ----------
# gates---
#  {'rz': 275, 'rx': 0, 'sx': 100, 'cx': 192, 'swap': 198, 'x': 8, 'measure': 5}
#
#
# Cost of the circuit: 7960
# tp assignment improved -  1  most used qubit - ok
#
# gates---
#  {'rz': 275, 'rx': 0, 'sx': 100, 'cx': 192, 'swap': 198, 'x': 8, 'measure': 5}
#
#
# Cost of the circuit: 7960
# tp assignment improved - v2 -  1  most used qubit - ok
#
# gates---
#  {'rz': 275, 'rx': 0, 'sx': 100, 'cx': 192, 'swap': 273, 'x': 8, 'measure': 5}
#
#
# Cost of the circuit: 10210
# tp assignment improved -  2  most used qubit - ok
#
# gates---
#  {'rz': 275, 'rx': 0, 'sx': 100, 'cx': 192, 'swap': 198, 'x': 8, 'measure': 5}
#
#
# Cost of the circuit: 7960
# tp assignment improved - v2 -  2  most used qubit - ok
#
# gates---
#  {'rz': 275, 'rx': 0, 'sx': 100, 'cx': 192, 'swap': 139, 'x': 8, 'measure': 5}
#
#
# Cost of the circuit: 6190
# tp assignment improved -  3  most used qubit - ok
#
# gates---
#  {'rz': 275, 'rx': 0, 'sx': 100, 'cx': 192, 'swap': 142, 'x': 8, 'measure': 5}
#
#
# Cost of the circuit: 6280
# tp assignment improved - v2 -  3  most used qubit - ok
#
# gates---
#  {'rz': 275, 'rx': 0, 'sx': 100, 'cx': 192, 'swap': 110, 'x': 8, 'measure': 5}
#
#
# Cost of the circuit: 5320
# tp assignment improved -  4  most used qubit - ok
#
# gates---
#  {'rz': 275, 'rx': 0, 'sx': 100, 'cx': 192, 'swap': 110, 'x': 8, 'measure': 5}
#
#
# Cost of the circuit: 5320
# tp assignment improved - v2 -  4  most used qubit - ok
#
# gates---
#  {'rz': 275, 'rx': 0, 'sx': 100, 'cx': 192, 'swap': 142, 'x': 8, 'measure': 5}
#
#
# Cost of the circuit: 6280
# tp assignment improved -  5  most used qubit - ok
#
# gates---
#  {'rz': 275, 'rx': 0, 'sx': 100, 'cx': 192, 'swap': 142, 'x': 8, 'measure': 5}
#
#
# Cost of the circuit: 6280
# tp assignment improved - v2 -  5  most used qubit - ok
#
# tot------ [7960, 7960, 10210, 7960, 6190, 6280, 5320, 5320, 6280, 6280]
# ------------iteration  12 -----------  file:  .\..\original\grover-6.qasm ----------
# gates---
#  {'rz': 504, 'rx': 0, 'sx': 183, 'cx': 360, 'swap': 700, 'x': 12, 'measure': 6}
#
#
# Cost of the circuit: 24783
# tp assignment improved -  1  most used qubit - ok
#
# gates---
#  {'rz': 504, 'rx': 0, 'sx': 183, 'cx': 360, 'swap': 695, 'x': 12, 'measure': 6}
#
#
# Cost of the circuit: 24633
# tp assignment improved - v2 -  1  most used qubit - ok
#
# gates---
#  {'rz': 504, 'rx': 0, 'sx': 183, 'cx': 360, 'swap': 673, 'x': 12, 'measure': 6}
#
#
# Cost of the circuit: 23973
# tp assignment improved -  2  most used qubit - ok
#
# gates---
#  {'rz': 504, 'rx': 0, 'sx': 183, 'cx': 360, 'swap': 303, 'x': 12, 'measure': 6}
#
#
# Cost of the circuit: 12873
# tp assignment improved - v2 -  2  most used qubit - ok
#
# gates---
#  {'rz': 504, 'rx': 0, 'sx': 183, 'cx': 360, 'swap': 211, 'x': 12, 'measure': 6}
#
#
# Cost of the circuit: 10113
# tp assignment improved -  3  most used qubit - ok
#
# gates---
#  {'rz': 504, 'rx': 0, 'sx': 183, 'cx': 360, 'swap': 211, 'x': 12, 'measure': 6}
#
#
# Cost of the circuit: 10113
# tp assignment improved - v2 -  3  most used qubit - ok
#
# gates---
#  {'rz': 504, 'rx': 0, 'sx': 183, 'cx': 360, 'swap': 215, 'x': 12, 'measure': 6}
#
#
# Cost of the circuit: 10233
# tp assignment improved -  4  most used qubit - ok
#
# gates---
#  {'rz': 504, 'rx': 0, 'sx': 183, 'cx': 360, 'swap': 304, 'x': 12, 'measure': 6}
#
#
# Cost of the circuit: 12903
# tp assignment improved - v2 -  4  most used qubit - ok
#
# gates---
#  {'rz': 504, 'rx': 0, 'sx': 183, 'cx': 360, 'swap': 215, 'x': 12, 'measure': 6}
#
#
# Cost of the circuit: 10233
# tp assignment improved -  5  most used qubit - ok
#
# gates---
#  {'rz': 504, 'rx': 0, 'sx': 183, 'cx': 360, 'swap': 215, 'x': 12, 'measure': 6}
#
#
# Cost of the circuit: 10233
# tp assignment improved - v2 -  5  most used qubit - ok
#
# tot------ [24783, 24633, 23973, 12873, 10113, 10113, 10233, 12903, 10233, 10233]
# ------------iteration  13 -----------  file:  .\..\original\grover-7.qasm ----------
# gates---
#  {'rz': 797, 'rx': 0, 'sx': 290, 'cx': 576, 'swap': 968, 'x': 16, 'measure': 7}
#
#
# Cost of the circuit: 35090
# tp assignment improved -  1  most used qubit - ok
#
# gates---
#  {'rz': 797, 'rx': 0, 'sx': 290, 'cx': 576, 'swap': 719, 'x': 16, 'measure': 7}
#
#
# Cost of the circuit: 27620
# tp assignment improved - v2 -  1  most used qubit - ok
#
# gates---
#  {'rz': 797, 'rx': 0, 'sx': 290, 'cx': 576, 'swap': 595, 'x': 16, 'measure': 7}
#
#
# Cost of the circuit: 23900
# tp assignment improved -  2  most used qubit - ok
#
# gates---
#  {'rz': 797, 'rx': 0, 'sx': 290, 'cx': 576, 'swap': 928, 'x': 16, 'measure': 7}
#
#
# Cost of the circuit: 33890
# tp assignment improved - v2 -  2  most used qubit - ok
#
# gates---
#  {'rz': 797, 'rx': 0, 'sx': 290, 'cx': 576, 'swap': 629, 'x': 16, 'measure': 7}
#
#
# Cost of the circuit: 24920
# tp assignment improved -  3  most used qubit - ok
#
# gates---
#  {'rz': 797, 'rx': 0, 'sx': 290, 'cx': 576, 'swap': 626, 'x': 16, 'measure': 7}
#
#
# Cost of the circuit: 24830
# tp assignment improved - v2 -  3  most used qubit - ok
#
# gates---
#  {'rz': 797, 'rx': 0, 'sx': 290, 'cx': 576, 'swap': 630, 'x': 16, 'measure': 7}
#
#
# Cost of the circuit: 24950
# tp assignment improved -  4  most used qubit - ok
#
# gates---
#  {'rz': 797, 'rx': 0, 'sx': 290, 'cx': 576, 'swap': 929, 'x': 16, 'measure': 7}
#
#
# Cost of the circuit: 33920
# tp assignment improved - v2 -  4  most used qubit - ok
# gates---
#  {'rz': 797, 'rx': 0, 'sx': 290, 'cx': 576, 'swap': 476, 'x': 16, 'measure': 7}
#
#
# Cost of the circuit: 20330
# tp assignment improved -  5  most used qubit - ok
#
# gates---
#  {'rz': 797, 'rx': 0, 'sx': 290, 'cx': 576, 'swap': 476, 'x': 16, 'measure': 7}
#
#
# Cost of the circuit: 20330
# tp assignment improved - v2 -  5  most used qubit - ok
#
# tot------ [35090, 27620, 23900, 33890, 24920, 24830, 24950, 33920, 20330, 20330]
# ------------iteration  14 -----------  file:  .\..\original\multiplier-2.qasm ----------
# gates---
#  {'rz': 163, 'rx': 0, 'sx': 8, 'cx': 152, 'swap': 145, 'barrier': 1, 'measure': 8}
#
#
# Cost of the circuit: 5878
# tp assignment improved -  1  most used qubit - ok
#
# gates---
#  {'rz': 163, 'rx': 0, 'sx': 8, 'cx': 152, 'swap': 150, 'barrier': 1, 'measure': 8}
#
#
# Cost of the circuit: 6028
# tp assignment improved - v2 -  1  most used qubit - ok
#
# gates---
#  {'rz': 163, 'rx': 0, 'sx': 8, 'cx': 152, 'swap': 119, 'barrier': 1, 'measure': 8}
#
#
# Cost of the circuit: 5098
# tp assignment improved -  2  most used qubit - ok
#
# gates---
#  {'rz': 163, 'rx': 0, 'sx': 8, 'cx': 152, 'swap': 119, 'barrier': 1, 'measure': 8}
#
#
# Cost of the circuit: 5098
# tp assignment improved - v2 -  2  most used qubit - ok
#
# gates---
#  {'rz': 163, 'rx': 0, 'sx': 8, 'cx': 152, 'swap': 119, 'barrier': 1, 'measure': 8}
#
#
# Cost of the circuit: 5098
# tp assignment improved -  3  most used qubit - ok
#
# gates---
#  {'rz': 163, 'rx': 0, 'sx': 8, 'cx': 152, 'swap': 122, 'barrier': 1, 'measure': 8}
#
#
# Cost of the circuit: 5188
# tp assignment improved - v2 -  3  most used qubit - ok
#
# gates---
#  {'rz': 163, 'rx': 0, 'sx': 8, 'cx': 152, 'swap': 119, 'barrier': 1, 'measure': 8}
#
#
# Cost of the circuit: 5098
# tp assignment improved -  4  most used qubit - ok
#
# gates---
#  {'rz': 163, 'rx': 0, 'sx': 8, 'cx': 152, 'swap': 119, 'barrier': 1, 'measure': 8}
#
#
# Cost of the circuit: 5098
# tp assignment improved - v2 -  4  most used qubit - ok
#
# gates---
#  {'rz': 163, 'rx': 0, 'sx': 8, 'cx': 152, 'swap': 126, 'barrier': 1, 'measure': 8}
#
#
# Cost of the circuit: 5308
# tp assignment improved -  5  most used qubit - ok
#
# gates---
#  {'rz': 163, 'rx': 0, 'sx': 8, 'cx': 152, 'swap': 143, 'barrier': 1, 'measure': 8}
#
#
# Cost of the circuit: 5818
# tp assignment improved - v2 -  5  most used qubit - ok
#
# tot------ [5878, 6028, 5098, 5098, 5098, 5188, 5098, 5098, 5308, 5818]
# ------------iteration  15 -----------  file:  .\..\original\multiplier-3.qasm ----------
# gates---
#  {'rz': 476, 'rx': 0, 'sx': 12, 'cx': 460, 'swap': 539, 'barrier': 1, 'measure': 12}
#
#
# Cost of the circuit: 20782
# tp assignment improved -  1  most used qubit - ok
#
# gates---
#  {'rz': 476, 'rx': 0, 'sx': 12, 'cx': 460, 'swap': 471, 'barrier': 1, 'measure': 12}
#
#
# Cost of the circuit: 18742
# tp assignment improved - v2 -  1  most used qubit - ok
#
# gates---
#  {'rz': 476, 'rx': 0, 'sx': 12, 'cx': 460, 'swap': 498, 'barrier': 1, 'measure': 12}
#
#
# Cost of the circuit: 19552
# tp assignment improved -  2  most used qubit - ok
#
# gates---
#  {'rz': 476, 'rx': 0, 'sx': 12, 'cx': 460, 'swap': 485, 'barrier': 1, 'measure': 12}
#
#
# Cost of the circuit: 19162
# tp assignment improved - v2 -  2  most used qubit - ok
#
# gates---
#  {'rz': 476, 'rx': 0, 'sx': 12, 'cx': 460, 'swap': 524, 'barrier': 1, 'measure': 12}
#
#
# Cost of the circuit: 20332
# tp assignment improved -  3  most used qubit - ok
#
# gates---
#  {'rz': 476, 'rx': 0, 'sx': 12, 'cx': 460, 'swap': 553, 'barrier': 1, 'measure': 12}
#
#
# Cost of the circuit: 21202
# tp assignment improved - v2 -  3  most used qubit - ok
#
# gates---
#  {'rz': 476, 'rx': 0, 'sx': 12, 'cx': 460, 'swap': 513, 'barrier': 1, 'measure': 12}
#
#
# Cost of the circuit: 20002
# tp assignment improved -  4  most used qubit - ok
#
# gates---
#  {'rz': 476, 'rx': 0, 'sx': 12, 'cx': 460, 'swap': 554, 'barrier': 1, 'measure': 12}
#
#
# Cost of the circuit: 21232
# tp assignment improved - v2 -  4  most used qubit - ok
#
# gates---
#  {'rz': 476, 'rx': 0, 'sx': 12, 'cx': 460, 'swap': 507, 'barrier': 1, 'measure': 12}
#
#
# Cost of the circuit: 19822
# tp assignment improved -  5  most used qubit - ok
#
# gates---
#  {'rz': 476, 'rx': 0, 'sx': 12, 'cx': 460, 'swap': 554, 'barrier': 1, 'measure': 12}
#
#
# Cost of the circuit: 21232
# tp assignment improved - v2 -  5  most used qubit - ok
#
# tot------ [20782, 18742, 19552, 19162, 20332, 21202, 20002, 21232, 19822, 21232]
# ------------iteration  16 -----------  file:  .\..\original\multiplier-4.qasm ----------
# gates---
#  {'rz': 997, 'rx': 0, 'sx': 16, 'cx': 976, 'swap': 1046, 'barrier': 1, 'measure': 16}
#
#
# Cost of the circuit: 41156
# tp assignment improved -  1  most used qubit - ok
#
# gates---
#  {'rz': 997, 'rx': 0, 'sx': 16, 'cx': 976, 'swap': 1575, 'barrier': 1, 'measure': 16}
#
#
# Cost of the circuit: 57026
# tp assignment improved - v2 -  1  most used qubit - ok
#
# gates---
#  {'rz': 997, 'rx': 0, 'sx': 16, 'cx': 976, 'swap': 1085, 'barrier': 1, 'measure': 16}
#
#
# Cost of the circuit: 42326
# tp assignment improved -  2  most used qubit - ok
#
# gates---
#  {'rz': 997, 'rx': 0, 'sx': 16, 'cx': 976, 'swap': 1367, 'barrier': 1, 'measure': 16}
#
#
# Cost of the circuit: 50786
# tp assignment improved - v2 -  2  most used qubit - ok
#
# gates---
#  {'rz': 997, 'rx': 0, 'sx': 16, 'cx': 976, 'swap': 1276, 'barrier': 1, 'measure': 16}
#
#
# Cost of the circuit: 48056
# tp assignment improved -  3  most used qubit - ok
#
# gates---
#  {'rz': 997, 'rx': 0, 'sx': 16, 'cx': 976, 'swap': 1438, 'barrier': 1, 'measure': 16}
#
#
# Cost of the circuit: 52916
# tp assignment improved - v2 -  3  most used qubit - ok
#
# gates---
#  {'rz': 997, 'rx': 0, 'sx': 16, 'cx': 976, 'swap': 1349, 'barrier': 1, 'measure': 16}
#
#
# Cost of the circuit: 50246
# tp assignment improved -  4  most used qubit - ok
#
# gates---
#  {'rz': 997, 'rx': 0, 'sx': 16, 'cx': 976, 'swap': 1326, 'barrier': 1, 'measure': 16}
#
#
# Cost of the circuit: 49556
# tp assignment improved - v2 -  4  most used qubit - ok
#
# gates---
#  {'rz': 997, 'rx': 0, 'sx': 16, 'cx': 976, 'swap': 1308, 'barrier': 1, 'measure': 16}
#
#
# Cost of the circuit: 49016
# tp assignment improved -  5  most used qubit - ok
#
# gates---
#  {'rz': 997, 'rx': 0, 'sx': 16, 'cx': 976, 'swap': 1395, 'barrier': 1, 'measure': 16}
#
#
# Cost of the circuit: 51626
# tp assignment improved - v2 -  5  most used qubit - ok
#
# tot------ [41156, 57026, 42326, 50786, 48056, 52916, 50246, 49556, 49016, 51626]
# ------------iteration  17 -----------  file:  .\..\original\qft-16.qasm ----------
# gates---
#  {'rz': 257, 'rx': 0, 'sx': 16, 'cx': 240, 'swap': 442, 'measure': 16}
#
#
# Cost of the circuit: 15676
# tp assignment improved -  1  most used qubit - ok
#
# gates---
#  {'rz': 257, 'rx': 0, 'sx': 16, 'cx': 240, 'swap': 293, 'measure': 16}
#
#
# Cost of the circuit: 11206
# tp assignment improved - v2 -  1  most used qubit - ok
#
# gates---
#  {'rz': 257, 'rx': 0, 'sx': 16, 'cx': 240, 'swap': 416, 'measure': 16}
#
#
# Cost of the circuit: 14896
# tp assignment improved -  2  most used qubit - ok
#
# gates---
#  {'rz': 257, 'rx': 0, 'sx': 16, 'cx': 240, 'swap': 295, 'measure': 16}
#
#
# Cost of the circuit: 11266
# tp assignment improved - v2 -  2  most used qubit - ok
#
# gates---
#  {'rz': 257, 'rx': 0, 'sx': 16, 'cx': 240, 'swap': 402, 'measure': 16}
#
#
# Cost of the circuit: 14476
# tp assignment improved -  3  most used qubit - ok
#
# gates---
#  {'rz': 257, 'rx': 0, 'sx': 16, 'cx': 240, 'swap': 336, 'measure': 16}
#
#
# Cost of the circuit: 12496
# tp assignment improved - v2 -  3  most used qubit - ok
#
# gates---
#  {'rz': 257, 'rx': 0, 'sx': 16, 'cx': 240, 'swap': 445, 'measure': 16}
#
#
# Cost of the circuit: 15766
# tp assignment improved -  4  most used qubit - ok
#
# gates---
#  {'rz': 257, 'rx': 0, 'sx': 16, 'cx': 240, 'swap': 317, 'measure': 16}
#
#
# Cost of the circuit: 11926
# tp assignment improved - v2 -  4  most used qubit - ok
#
# gates---
#  {'rz': 257, 'rx': 0, 'sx': 16, 'cx': 240, 'swap': 402, 'measure': 16}
#
#
# Cost of the circuit: 14476
# tp assignment improved -  5  most used qubit - ok
#
# gates---
#  {'rz': 257, 'rx': 0, 'sx': 16, 'cx': 240, 'swap': 315, 'measure': 16}
#
#
# Cost of the circuit: 11866
# tp assignment improved - v2 -  5  most used qubit - ok
#
# tot------ [15676, 11206, 14896, 11266, 14476, 12496, 15766, 11926, 14476, 11866]
# ------------iteration  18 -----------  file:  .\..\original\qft-27.qasm ----------
# gates---
#  {'rz': 640, 'rx': 0, 'sx': 27, 'cx': 612, 'swap': 1484, 'measure': 27}
#
#
# Cost of the circuit: 50667
# tp assignment improved -  1  most used qubit - ok
# gates---
#  {'rz': 640, 'rx': 0, 'sx': 27, 'cx': 612, 'swap': 1098, 'measure': 27}
#
#
# Cost of the circuit: 39087
# tp assignment improved - v2 -  1  most used qubit - ok
#
# gates---
#  {'rz': 640, 'rx': 0, 'sx': 27, 'cx': 612, 'swap': 1373, 'measure': 27}
#
#
# Cost of the circuit: 47337
# tp assignment improved -  2  most used qubit - ok
#
# gates---
#  {'rz': 640, 'rx': 0, 'sx': 27, 'cx': 612, 'swap': 1274, 'measure': 27}
#
#
# Cost of the circuit: 44367
# tp assignment improved - v2 -  2  most used qubit - ok
#
# gates---
#  {'rz': 640, 'rx': 0, 'sx': 27, 'cx': 612, 'swap': 1448, 'measure': 27}
#
#
# Cost of the circuit: 49587
# tp assignment improved -  3  most used qubit - ok
#
# gates---
#  {'rz': 640, 'rx': 0, 'sx': 27, 'cx': 612, 'swap': 1345, 'measure': 27}
#
#
# Cost of the circuit: 46497
# tp assignment improved - v2 -  3  most used qubit - ok
#
# gates---
#  {'rz': 640, 'rx': 0, 'sx': 27, 'cx': 612, 'swap': 1393, 'measure': 27}
#
#
# Cost of the circuit: 47937
# tp assignment improved -  4  most used qubit - ok
#
# gates---
#  {'rz': 640, 'rx': 0, 'sx': 27, 'cx': 612, 'swap': 1266, 'measure': 27}
#
#
# Cost of the circuit: 44127
# tp assignment improved - v2 -  4  most used qubit - ok
#
# gates---
#  {'rz': 640, 'rx': 0, 'sx': 27, 'cx': 612, 'swap': 1634, 'measure': 27}
#
#
# Cost of the circuit: 55167
# tp assignment improved -  5  most used qubit - ok
#
# gates---
#  {'rz': 640, 'rx': 0, 'sx': 27, 'cx': 612, 'swap': 1191, 'measure': 27}
#
#
# Cost of the circuit: 41877
# tp assignment improved - v2 -  5  most used qubit - ok
#
# tot------ [50667, 39087, 47337, 44367, 49587, 46497, 47937, 44127, 55167, 41877]
# ------------iteration  19 -----------  file:  .\..\original\qft-5.qasm ----------
# gates---
#  {'rz': 26, 'rx': 0, 'sx': 5, 'cx': 20, 'swap': 12, 'measure': 5}
#
#
# Cost of the circuit: 565
# tp assignment improved -  1  most used qubit - ok
#
# gates---
#  {'rz': 26, 'rx': 0, 'sx': 5, 'cx': 20, 'swap': 10, 'measure': 5}
#
#
# Cost of the circuit: 505
# tp assignment improved - v2 -  1  most used qubit - ok
#
# gates---
#  {'rz': 26, 'rx': 0, 'sx': 5, 'cx': 20, 'swap': 12, 'measure': 5}
#
#
# Cost of the circuit: 565
# tp assignment improved -  2  most used qubit - ok
#
# gates---
#  {'rz': 26, 'rx': 0, 'sx': 5, 'cx': 20, 'swap': 11, 'measure': 5}
#
#
# Cost of the circuit: 535
# tp assignment improved - v2 -  2  most used qubit - ok
#
# gates---
#  {'rz': 26, 'rx': 0, 'sx': 5, 'cx': 20, 'swap': 12, 'measure': 5}
#
#
# Cost of the circuit: 565
# tp assignment improved -  3  most used qubit - ok
#
# gates---
#  {'rz': 26, 'rx': 0, 'sx': 5, 'cx': 20, 'swap': 20, 'measure': 5}
#
#
# Cost of the circuit: 805
# tp assignment improved - v2 -  3  most used qubit - ok
#
# gates---
#  {'rz': 26, 'rx': 0, 'sx': 5, 'cx': 20, 'swap': 14, 'measure': 5}
#
#
# Cost of the circuit: 625
# tp assignment improved -  4  most used qubit - ok
#
# gates---
#  {'rz': 26, 'rx': 0, 'sx': 5, 'cx': 20, 'swap': 20, 'measure': 5}
#
#
# Cost of the circuit: 805
# tp assignment improved - v2 -  4  most used qubit - ok
#
# gates---
#  {'rz': 26, 'rx': 0, 'sx': 5, 'cx': 20, 'swap': 20, 'measure': 5}
#
#
# Cost of the circuit: 805
# tp assignment improved -  5  most used qubit - ok
#
# gates---
#  {'rz': 26, 'rx': 0, 'sx': 5, 'cx': 20, 'swap': 20, 'measure': 5}
#
#
# Cost of the circuit: 805
# tp assignment improved - v2 -  5  most used qubit - ok
#
# tot------ [565, 505, 565, 535, 565, 805, 625, 805, 805, 805]
# ------------iteration  20 -----------  file:  .\..\original\qft-7.qasm ----------
# gates---
#  {'rz': 50, 'rx': 0, 'sx': 7, 'cx': 42, 'swap': 34, 'measure': 7}
#
#
# Cost of the circuit: 1447
# tp assignment improved -  1  most used qubit - ok
#
# gates---
#  {'rz': 50, 'rx': 0, 'sx': 7, 'cx': 42, 'swap': 51, 'measure': 7}
#
#
# Cost of the circuit: 1957
# tp assignment improved - v2 -  1  most used qubit - ok
#
# gates---
#  {'rz': 50, 'rx': 0, 'sx': 7, 'cx': 42, 'swap': 34, 'measure': 7}
#
#
# Cost of the circuit: 1447
# tp assignment improved -  2  most used qubit - ok
#
# gates---
#  {'rz': 50, 'rx': 0, 'sx': 7, 'cx': 42, 'swap': 51, 'measure': 7}
#
#
# Cost of the circuit: 1957
# tp assignment improved - v2 -  2  most used qubit - ok
#
# gates---
#  {'rz': 50, 'rx': 0, 'sx': 7, 'cx': 42, 'swap': 41, 'measure': 7}
#
#
# Cost of the circuit: 1657
# tp assignment improved -  3  most used qubit - ok
#
# gates---
#  {'rz': 50, 'rx': 0, 'sx': 7, 'cx': 42, 'swap': 70, 'measure': 7}
#
#
# Cost of the circuit: 2527
# tp assignment improved - v2 -  3  most used qubit - ok
#
# gates---
#  {'rz': 50, 'rx': 0, 'sx': 7, 'cx': 42, 'swap': 48, 'measure': 7}
#
#
# Cost of the circuit: 1867
# tp assignment improved -  4  most used qubit - ok
#
# gates---
#  {'rz': 50, 'rx': 0, 'sx': 7, 'cx': 42, 'swap': 70, 'measure': 7}
#
#
# Cost of the circuit: 2527
# tp assignment improved - v2 -  4  most used qubit - ok
#
# gates---
#  {'rz': 50, 'rx': 0, 'sx': 7, 'cx': 42, 'swap': 51, 'measure': 7}
#
#
# Cost of the circuit: 1957
# tp assignment improved -  5  most used qubit - ok
#
# gates---
#  {'rz': 50, 'rx': 0, 'sx': 7, 'cx': 42, 'swap': 70, 'measure': 7}
#
#
# Cost of the circuit: 2527
# tp assignment improved - v2 -  5  most used qubit - ok
#
# tot------ [1447, 1957, 1447, 1957, 1657, 2527, 1867, 2527, 1957, 2527]
# ------------iteration  21 -----------  file:  .\..\original\qpe-15.qasm ----------
# gates---
#  {'rz': 300, 'rx': 0, 'sx': 30, 'cx': 261, 'swap': 361, 'x': 1, 'measure': 15}
#
#
# Cost of the circuit: 13470
# tp assignment improved -  1  most used qubit - ok
#
# gates---
#  {'rz': 300, 'rx': 0, 'sx': 30, 'cx': 261, 'swap': 342, 'x': 1, 'measure': 15}
#
#
# Cost of the circuit: 12900
# tp assignment improved - v2 -  1  most used qubit - ok
#
# gates---
#  {'rz': 300, 'rx': 0, 'sx': 30, 'cx': 261, 'swap': 376, 'x': 1, 'measure': 15}
#
#
# Cost of the circuit: 13920
# tp assignment improved -  2  most used qubit - ok
#
# gates---
#  {'rz': 300, 'rx': 0, 'sx': 30, 'cx': 261, 'swap': 369, 'x': 1, 'measure': 15}
#
#
# Cost of the circuit: 13710
# tp assignment improved - v2 -  2  most used qubit - ok
#
# gates---
#  {'rz': 300, 'rx': 0, 'sx': 30, 'cx': 261, 'swap': 340, 'x': 1, 'measure': 15}
#
#
# Cost of the circuit: 12840
# tp assignment improved -  3  most used qubit - ok
#
# gates---
#  {'rz': 300, 'rx': 0, 'sx': 30, 'cx': 261, 'swap': 303, 'x': 1, 'measure': 15}
#
#
# Cost of the circuit: 11730
# tp assignment improved - v2 -  3  most used qubit - ok
#
# gates---
#  {'rz': 300, 'rx': 0, 'sx': 30, 'cx': 261, 'swap': 407, 'x': 1, 'measure': 15}
#
#
# Cost of the circuit: 14850
# tp assignment improved -  4  most used qubit - ok
#
# gates---
#  {'rz': 300, 'rx': 0, 'sx': 30, 'cx': 261, 'swap': 401, 'x': 1, 'measure': 15}
#
#
# Cost of the circuit: 14670
# tp assignment improved - v2 -  4  most used qubit - ok
#
# gates---
#  {'rz': 300, 'rx': 0, 'sx': 30, 'cx': 261, 'swap': 374, 'x': 1, 'measure': 15}
#
#
# Cost of the circuit: 13860
# tp assignment improved -  5  most used qubit - ok
#
# gates---
#  {'rz': 300, 'rx': 0, 'sx': 30, 'cx': 261, 'swap': 376, 'x': 1, 'measure': 15}
#
#
# Cost of the circuit: 13920
# tp assignment improved - v2 -  5  most used qubit - ok
#
# tot------ [13470, 12900, 13920, 13710, 12840, 11730, 14850, 14670, 13860, 13920]
# ------------iteration  22 -----------  file:  .\..\original\qpe-26.qasm ----------
# gates---
#  {'rz': 725, 'rx': 0, 'sx': 52, 'cx': 667, 'swap': 1258, 'x': 1, 'measure': 26}
#
#
# Cost of the circuit: 44462
# tp assignment improved -  1  most used qubit - ok
#
# gates---
#  {'rz': 725, 'rx': 0, 'sx': 52, 'cx': 667, 'swap': 1125, 'x': 1, 'measure': 26}
#
#
# Cost of the circuit: 40472
# tp assignment improved - v2 -  1  most used qubit - ok
#
# gates---
#  {'rz': 725, 'rx': 0, 'sx': 52, 'cx': 667, 'swap': 1294, 'x': 1, 'measure': 26}
#
#
# Cost of the circuit: 45542
# tp assignment improved -  2  most used qubit - ok
#
# gates---
#  {'rz': 725, 'rx': 0, 'sx': 52, 'cx': 667, 'swap': 1222, 'x': 1, 'measure': 26}
#
#
# Cost of the circuit: 43382
# tp assignment improved - v2 -  2  most used qubit - ok
#
# gates---
#  {'rz': 725, 'rx': 0, 'sx': 52, 'cx': 667, 'swap': 1281, 'x': 1, 'measure': 26}
#
#
# Cost of the circuit: 45152
# tp assignment improved -  3  most used qubit - ok
#
# gates---
#  {'rz': 725, 'rx': 0, 'sx': 52, 'cx': 667, 'swap': 1253, 'x': 1, 'measure': 26}
#
#
# Cost of the circuit: 44312
# tp assignment improved - v2 -  3  most used qubit - ok
#
# gates---
#  {'rz': 725, 'rx': 0, 'sx': 52, 'cx': 667, 'swap': 1146, 'x': 1, 'measure': 26}
#
#
# Cost of the circuit: 41102
# tp assignment improved -  4  most used qubit - ok
#
# gates---
#  {'rz': 725, 'rx': 0, 'sx': 52, 'cx': 667, 'swap': 1147, 'x': 1, 'measure': 26}
#
#
# Cost of the circuit: 41132
# tp assignment improved - v2 -  4  most used qubit - ok
# gates---
#  {'rz': 725, 'rx': 0, 'sx': 52, 'cx': 667, 'swap': 1300, 'x': 1, 'measure': 26}
#
#
# Cost of the circuit: 45722
# tp assignment improved -  5  most used qubit - ok
#
# gates---
#  {'rz': 725, 'rx': 0, 'sx': 52, 'cx': 667, 'swap': 1239, 'x': 1, 'measure': 26}
#
#
# Cost of the circuit: 43892
# tp assignment improved - v2 -  5  most used qubit - ok
#
# tot------ [44462, 40472, 45542, 43382, 45152, 44312, 41102, 41132, 45722, 43892]
# ------------iteration  23 -----------  file:  .\..\original\qpe-4.qasm ----------
# gates---
#  {'rz': 37, 'rx': 0, 'sx': 8, 'cx': 26, 'swap': 9, 'x': 1, 'measure': 4}
#
#
# Cost of the circuit: 538
# tp assignment improved -  1  most used qubit - ok
#
# gates---
#  {'rz': 37, 'rx': 0, 'sx': 8, 'cx': 26, 'swap': 14, 'x': 1, 'measure': 4}
#
#
# Cost of the circuit: 688
# tp assignment improved - v2 -  1  most used qubit - ok
#
# gates---
#  {'rz': 37, 'rx': 0, 'sx': 8, 'cx': 26, 'swap': 8, 'x': 1, 'measure': 4}
#
#
# Cost of the circuit: 508
# tp assignment improved -  2  most used qubit - ok
#
# gates---
#  {'rz': 37, 'rx': 0, 'sx': 8, 'cx': 26, 'swap': 14, 'x': 1, 'measure': 4}
#
#
# Cost of the circuit: 688
# tp assignment improved - v2 -  2  most used qubit - ok
#
# gates---
#  {'rz': 37, 'rx': 0, 'sx': 8, 'cx': 26, 'swap': 10, 'x': 1, 'measure': 4}
#
#
# Cost of the circuit: 568
# tp assignment improved -  3  most used qubit - ok
#
# gates---
#  {'rz': 37, 'rx': 0, 'sx': 8, 'cx': 26, 'swap': 14, 'x': 1, 'measure': 4}
#
#
# Cost of the circuit: 688
# tp assignment improved - v2 -  3  most used qubit - ok
#
# gates---
#  {'rz': 37, 'rx': 0, 'sx': 8, 'cx': 26, 'swap': 14, 'x': 1, 'measure': 4}
#
#
# Cost of the circuit: 688
# tp assignment improved -  4  most used qubit - ok
#
# gates---
#  {'rz': 37, 'rx': 0, 'sx': 8, 'cx': 26, 'swap': 14, 'x': 1, 'measure': 4}
#
#
# Cost of the circuit: 688
# tp assignment improved - v2 -  4  most used qubit - ok
#
# gates---
#  {'rz': 37, 'rx': 0, 'sx': 8, 'cx': 26, 'swap': 16, 'x': 1, 'measure': 4}
#
#
# Cost of the circuit: 748
# tp assignment improved -  5  most used qubit - ok
#
# gates---
#  {'rz': 37, 'rx': 0, 'sx': 8, 'cx': 26, 'swap': 16, 'x': 1, 'measure': 4}
#
#
# Cost of the circuit: 748
# tp assignment improved - v2 -  5  most used qubit - ok
#
# tot------ [538, 688, 508, 688, 568, 688, 688, 688, 748, 748]
# ------------iteration  24 -----------  file:  .\..\original\qpe-6.qasm ----------
# gates---
#  {'rz': 61, 'rx': 0, 'sx': 12, 'cx': 45, 'swap': 20, 'x': 1, 'measure': 6}
#
#
# Cost of the circuit: 1062
# tp assignment improved -  1  most used qubit - ok
#
# gates---
#  {'rz': 61, 'rx': 0, 'sx': 12, 'cx': 45, 'swap': 20, 'x': 1, 'measure': 6}
#
#
# Cost of the circuit: 1062
# tp assignment improved - v2 -  1  most used qubit - ok
#
# gates---
#  {'rz': 61, 'rx': 0, 'sx': 12, 'cx': 45, 'swap': 20, 'x': 1, 'measure': 6}
#
#
# Cost of the circuit: 1062
# tp assignment improved -  2  most used qubit - ok
#
# gates---
#  {'rz': 61, 'rx': 0, 'sx': 12, 'cx': 45, 'swap': 23, 'x': 1, 'measure': 6}
#
#
# Cost of the circuit: 1152
# tp assignment improved - v2 -  2  most used qubit - ok
#
# gates---
#  {'rz': 61, 'rx': 0, 'sx': 12, 'cx': 45, 'swap': 22, 'x': 1, 'measure': 6}
#
#
# Cost of the circuit: 1122
# tp assignment improved -  3  most used qubit - ok
#
# gates---
#  {'rz': 61, 'rx': 0, 'sx': 12, 'cx': 45, 'swap': 22, 'x': 1, 'measure': 6}
#
#
# Cost of the circuit: 1122
# tp assignment improved - v2 -  3  most used qubit - ok
#
# gates---
#  {'rz': 61, 'rx': 0, 'sx': 12, 'cx': 45, 'swap': 24, 'x': 1, 'measure': 6}
#
#
# Cost of the circuit: 1182
# tp assignment improved -  4  most used qubit - ok
#
# gates---
#  {'rz': 61, 'rx': 0, 'sx': 12, 'cx': 45, 'swap': 20, 'x': 1, 'measure': 6}
#
#
# Cost of the circuit: 1062
# tp assignment improved - v2 -  4  most used qubit - ok
#
# gates---
#  {'rz': 61, 'rx': 0, 'sx': 12, 'cx': 45, 'swap': 21, 'x': 1, 'measure': 6}
#
#
# Cost of the circuit: 1092
# tp assignment improved -  5  most used qubit - ok
#
# gates---
#  {'rz': 61, 'rx': 0, 'sx': 12, 'cx': 45, 'swap': 21, 'x': 1, 'measure': 6}
#
#
# Cost of the circuit: 1092
# tp assignment improved - v2 -  5  most used qubit - ok
#
# tot------ [1062, 1062, 1062, 1152, 1122, 1122, 1182, 1062, 1092, 1092]
# ------------iteration  25 -----------  file:  .\..\original\shor-3.qasm ----------
# gates---
#  {'rz': 1844, 'rx': 0, 'sx': 234, 'cx': 1650, 'swap': 1024, 'x': 3, 'measure': 4}
#
#
# Cost of the circuit: 47454
# tp assignment improved -  1  most used qubit - ok
#
# gates---
#  {'rz': 1844, 'rx': 0, 'sx': 234, 'cx': 1650, 'swap': 1102, 'x': 3, 'measure': 4}
#
#
# Cost of the circuit: 49794
# tp assignment improved - v2 -  1  most used qubit - ok
#
# gates---
#  {'rz': 1844, 'rx': 0, 'sx': 234, 'cx': 1650, 'swap': 1024, 'x': 3, 'measure': 4}
#
#
# Cost of the circuit: 47454
# tp assignment improved -  2  most used qubit - ok
#
# gates---
#  {'rz': 1844, 'rx': 0, 'sx': 234, 'cx': 1650, 'swap': 1094, 'x': 3, 'measure': 4}
#
#
# Cost of the circuit: 49554
# tp assignment improved - v2 -  2  most used qubit - ok
#
# gates---
#  {'rz': 1844, 'rx': 0, 'sx': 234, 'cx': 1650, 'swap': 1087, 'x': 3, 'measure': 4}
#
#
# Cost of the circuit: 49344
# tp assignment improved -  3  most used qubit - ok
#
# gates---
#  {'rz': 1844, 'rx': 0, 'sx': 234, 'cx': 1650, 'swap': 1116, 'x': 3, 'measure': 4}
#
#
# Cost of the circuit: 50214
# tp assignment improved - v2 -  3  most used qubit - ok
#
# gates---
#  {'rz': 1844, 'rx': 0, 'sx': 234, 'cx': 1650, 'swap': 1116, 'x': 3, 'measure': 4}
#
#
# Cost of the circuit: 50214
# tp assignment improved -  4  most used qubit - ok
#
# gates---
#  {'rz': 1844, 'rx': 0, 'sx': 234, 'cx': 1650, 'swap': 1182, 'x': 3, 'measure': 4}
#
#
# Cost of the circuit: 52194
# tp assignment improved - v2 -  4  most used qubit - ok
#
# gates---
#  {'rz': 1844, 'rx': 0, 'sx': 234, 'cx': 1650, 'swap': 1102, 'x': 3, 'measure': 4}
#
#
# Cost of the circuit: 49794
# tp assignment improved -  5  most used qubit - ok
#
# gates---
#  {'rz': 1844, 'rx': 0, 'sx': 234, 'cx': 1650, 'swap': 1103, 'x': 3, 'measure': 4}
#
#
# Cost of the circuit: 49824
# tp assignment improved - v2 -  5  most used qubit - ok
#
# tot------ [47454, 49794, 47454, 49554, 49344, 50214, 50214, 52194, 49794, 49824]
# ------------iteration  26 -----------  file:  .\..\original\test.qasm ----------
# gates---
#  {'rz': 12, 'rx': 0, 'sx': 2, 'cx': 6, 'swap': 1, 'barrier': 1, 'measure': 6}
#
#
# Cost of the circuit: 92
# tp assignment improved -  1  most used qubit - ok
#
# gates---
#  {'rz': 12, 'rx': 0, 'sx': 2, 'cx': 6, 'swap': 1, 'barrier': 1, 'measure': 6}
#
#
# Cost of the circuit: 92
# tp assignment improved - v2 -  1  most used qubit - ok
#
# gates---
#  {'rz': 12, 'rx': 0, 'sx': 2, 'cx': 6, 'swap': 1, 'barrier': 1, 'measure': 6}
#
#
# Cost of the circuit: 92
# tp assignment improved -  2  most used qubit - ok
#
# gates---
#  {'rz': 12, 'rx': 0, 'sx': 2, 'cx': 6, 'swap': 1, 'barrier': 1, 'measure': 6}
#
#
# Cost of the circuit: 92
# tp assignment improved - v2 -  2  most used qubit - ok
#
# gates---
#  {'rz': 12, 'rx': 0, 'sx': 2, 'cx': 6, 'swap': 2, 'barrier': 1, 'measure': 6}
#
#
# Cost of the circuit: 122
# tp assignment improved -  3  most used qubit - ok
#
# gates---
#  {'rz': 12, 'rx': 0, 'sx': 2, 'cx': 6, 'swap': 2, 'barrier': 1, 'measure': 6}
#
#
# Cost of the circuit: 122
# tp assignment improved - v2 -  3  most used qubit - ok
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14144/3521535509.py in <module>
#      11     input_path = filepaths[i]
#      12     qc = QuantumCircuit.from_qasm_file(path=input_path)
# ---> 13     costs = compare_cost(qc, n_most_used)
#      14     print('tot------', costs)
#      15     row = [input_path.rsplit('\\', 1)[1]]
#
# ~\AppData\Local\Temp/ipykernel_14144/3252087398.py in compare_cost(qc, n_most_used)
#      12
#      13         tpi = TopologicalAssignmentImproved(coupling_map)
# ---> 14         tp_layouti = tpi.run(new_device_DAG, n + 1) # n is from 0 to (n_most_used - 1)
#      15         basic_pass_modifiedi = BasicSwapModified(coupling_map, tp_layouti)
#      16         new_dag_tp_assignmnet_i = basic_pass_modifiedi.run(new_device_DAG)
#
# ~\OneDrive\Desktop\Emerging Computer Technology\emerging-computer-technologies-quantum-project\utils\TPImproved.py in run(self, dag, n_most_used)
#      76         most_used_qubits = self.most_involved(dag)
#      77         for n in range(n_most_used):
# ---> 78             layout_dict[most_used_qubits[n]] = i
#      79             i += 1
#      80
#
# IndexError: list index out of range

# %%
table = [['benchmark name', 'tpi_1', 'v2', 'tpi_2', 'v2', 'tpi_3', 'v2', 'tpi_4', 'v2', 'tpi_5', 'v2']]
table.extend(table_rows)

print('--------------------------- Cost in terms of gates-------------------------------------------------------')
print(tabulate(table,headers='firstrow', tablefmt='fancy_grid', numalign='center'))
# Out:
# --------------------------- Cost in terms of gates-------------------------------------------------------
# ╒═══════════════════╤═════════╤═══════╤═════════╤═══════╤═════════╤═══════╤═════════╤═══════╤═════════╤═══════╕
# │ benchmark name    │  tpi_1  │  v2   │  tpi_2  │  v2   │  tpi_3  │  v2   │  tpi_4  │  v2   │  tpi_5  │  v2   │
# ╞═══════════════════╪═════════╪═══════╪═════════╪═══════╪═════════╪═══════╪═════════╪═══════╪═════════╪═══════╡
# │ adder-13.qasm     │  25006  │ 27946 │  25246  │ 25606 │  26206  │ 27646 │  29056  │ 30046 │  31906  │ 27196 │
# ├───────────────────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┤
# │ adder-16.qasm     │  51172  │ 51262 │  45982  │ 44482 │  47812  │ 51592 │  49732  │ 53932 │  57442  │ 46432 │
# ├───────────────────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┤
# │ adder-3.qasm      │   576   │  546  │   576   │  546  │   576   │  636  │   576   │  636  │   546   │  606  │
# ├───────────────────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┤
# │ adder-8.qasm      │  7136   │ 7526  │  6926   │ 7076  │  7286   │ 8246  │  8096   │ 8216  │  7706   │ 8036  │
# ├───────────────────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┤
# │ ghz_state-16.qasm │   151   │  151  │   151   │  151  │   151   │  181  │   181   │  151  │   181   │  151  │
# ├───────────────────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┤
# │ ghz_state-27.qasm │   291   │  291  │   291   │  261  │   261   │  291  │   291   │  291  │   261   │  291  │
# ├───────────────────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┤
# │ ghz_state-5.qasm  │   41    │  41   │   41    │  41   │   41    │  41   │   161   │  161  │   131   │  131  │
# ├───────────────────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┤
# │ ghz_state-65.qasm │  1361   │ 1361  │  1121   │ 1601  │  1361   │ 1421  │  1301   │ 1181  │  1361   │ 1541  │
# ├───────────────────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┤
# │ ghz_state-7.qasm  │   61    │  61   │   61    │  61   │   61    │  61   │   61    │  61   │   61    │  61   │
# ├───────────────────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┤
# │ grover-3.qasm     │   896   │  896  │   896   │  896  │  1346   │ 1346  │  1346   │ 1346  │  1526   │ 1526  │
# ├───────────────────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┤
# │ grover-4.qasm     │  3477   │ 3477  │  3477   │ 3477  │  3567   │ 3897  │  3567   │ 2487  │  3567   │ 3567  │
# ├───────────────────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┤
# │ grover-5.qasm     │  7960   │ 7960  │  10210  │ 7960  │  6190   │ 6280  │  5320   │ 5320  │  6280   │ 6280  │
# ├───────────────────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┤
# │ grover-6.qasm     │  24783  │ 24633 │  23973  │ 12873 │  10113  │ 10113 │  10233  │ 12903 │  10233  │ 10233 │
# ├───────────────────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┤
# │ grover-7.qasm     │  35090  │ 27620 │  23900  │ 33890 │  24920  │ 24830 │  24950  │ 33920 │  20330  │ 20330 │
# ├───────────────────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┤
# │ multiplier-2.qasm │  5878   │ 6028  │  5098   │ 5098  │  5098   │ 5188  │  5098   │ 5098  │  5308   │ 5818  │
# ├───────────────────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┤
# │ multiplier-3.qasm │  20782  │ 18742 │  19552  │ 19162 │  20332  │ 21202 │  20002  │ 21232 │  19822  │ 21232 │
# ├───────────────────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┤
# │ multiplier-4.qasm │  41156  │ 57026 │  42326  │ 50786 │  48056  │ 52916 │  50246  │ 49556 │  49016  │ 51626 │
# ├───────────────────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┤
# │ qft-16.qasm       │  15676  │ 11206 │  14896  │ 11266 │  14476  │ 12496 │  15766  │ 11926 │  14476  │ 11866 │
# ├───────────────────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┤
# │ qft-27.qasm       │  50667  │ 39087 │  47337  │ 44367 │  49587  │ 46497 │  47937  │ 44127 │  55167  │ 41877 │
# ├───────────────────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┤
# │ qft-5.qasm        │   565   │  505  │   565   │  535  │   565   │  805  │   625   │  805  │   805   │  805  │
# ├───────────────────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┤
# │ qft-7.qasm        │  1447   │ 1957  │  1447   │ 1957  │  1657   │ 2527  │  1867   │ 2527  │  1957   │ 2527  │
# ├───────────────────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┤
# │ qpe-15.qasm       │  13470  │ 12900 │  13920  │ 13710 │  12840  │ 11730 │  14850  │ 14670 │  13860  │ 13920 │
# ├───────────────────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┤
# │ qpe-26.qasm       │  44462  │ 40472 │  45542  │ 43382 │  45152  │ 44312 │  41102  │ 41132 │  45722  │ 43892 │
# ├───────────────────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┤
# │ qpe-4.qasm        │   538   │  688  │   508   │  688  │   568   │  688  │   688   │  688  │   748   │  748  │
# ├───────────────────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┤
# │ qpe-6.qasm        │  1062   │ 1062  │  1062   │ 1152  │  1122   │ 1122  │  1182   │ 1062  │  1092   │ 1092  │
# ├───────────────────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┼─────────┼───────┤
# │ shor-3.qasm       │  47454  │ 49794 │  47454  │ 49554 │  49344  │ 50214 │  50214  │ 52194 │  49794  │ 49824 │
# ╘═══════════════════╧═════════╧═══════╧═════════╧═══════╧═════════╧═══════╧═════════╧═══════╧═════════╧═══════╛

# %% [markdown]
# # Let's compare
#
# Entire results have been saved in: ".\tpi-vs-tpiv2-compact.png"

# %%
# let's build a list with these elements:
# el0: number of tpi_1 costs > v2
# el1: number of tpi_1 cost < v2
# el2: number of tpi_1 cost = v2
# ...

# create list structure
comparison_list = []
for i in range(n_most_used):
    comparison_list.append([0, 0, 0])
    
for row in table_rows:
    for i in range(n_most_used):
        j = i * 2 + 1
        if row[j] > row[j+1]:
            comparison_list[i][0] += 1
        elif row[j] < row[j+1]:
            comparison_list[i][1] += 1
        else:
            comparison_list[i][2] += 1
# show results
for elem in range(n_most_used):
    print('\n\n --- tpi_', elem + 1, ' ---\n')
    print('n. cases where \t tpi cost > v2: \t', comparison_list[elem][0])
    print('n. cases where \t tpi cost < v2: \t', comparison_list[elem][1])
    print('n. cases where \t tpi cost = v2: \t', comparison_list[elem][2])
# Out:
#  --- tpi_ 1  ---
#
# n. cases where 	 tpi cost > v2: 	 9
# n. cases where 	 tpi cost < v2: 	 8
# n. cases where 	 tpi cost = v2: 	 9
#
#
#  --- tpi_ 2  ---
#
# n. cases where 	 tpi cost > v2: 	 11
# n. cases where 	 tpi cost < v2: 	 9
# n. cases where 	 tpi cost = v2: 	 6
#
#
#  --- tpi_ 3  ---
#
# n. cases where 	 tpi cost > v2: 	 5
# n. cases where 	 tpi cost < v2: 	 16
# n. cases where 	 tpi cost = v2: 	 5
#
#
#  --- tpi_ 4  ---
#
# n. cases where 	 tpi cost > v2: 	 8
# n. cases where 	 tpi cost < v2: 	 11
# n. cases where 	 tpi cost = v2: 	 7
#
#
#  --- tpi_ 5  ---
#
# n. cases where 	 tpi cost > v2: 	 6
# n. cases where 	 tpi cost < v2: 	 10
# n. cases where 	 tpi cost = v2: 	 10

# %% [markdown]
# It seems that using **more n-most-used-qubits** the v2 of TopologicalAssignmentImproved v2 performs much better, while **for n=1 or n=2** the previous version performs slightly better.
#
# The question would be: why?

# %% [markdown]
# # Conclusions
#
# Comparing every mapper with each other it's obvious that **the best one is the one which uses less n-most-used-qubits**. This is probably because **the most-used-qubits don't have a lot of interactions between each others** and we are statically mapping them to physical qubits which are close to each other (for convenience...).
#
# An improvement would be to find how much far away from each other is the best way to map these n-most-used-qubits.

# %%
# try to define the best one overall
best_costs_count = []
for i in range(n_most_used * 2):
    best_costs_count.append(0)

for row in table_rows:
    best_cost = min(row[1:])
    best_index = row.index(best_cost)
    best_costs_count[best_index - 1] += 1

print('\n\nNumber of times when the best is: ')
for i in range(n_most_used):
    print('\ntpi_', i + 1, ':\t', best_costs_count[i * 2])
    print('\ntpi_', i + 1, '(v2):\t', best_costs_count[i * 2 + 1])
# Out:
# Number of times when the best is:
#
# tpi_ 1 :	 9
#
# tpi_ 1 (v2):	 6
#
# tpi_ 2 :	 4
#
# tpi_ 2 (v2):	 2
#
# tpi_ 3 :	 1
#
# tpi_ 3 (v2):	 1
#
# tpi_ 4 :	 1
#
# tpi_ 4 (v2):	 1
#
# tpi_ 5 :	 1
#
# tpi_ 5 (v2):	 0
